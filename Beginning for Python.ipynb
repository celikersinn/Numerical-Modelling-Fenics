# %%
2+2
# Out:
# 4

# %%
5//2
# Out:
# 2

# %%
5 % 2
# Out:
# 1

# %%
a = 2.54

# %%
b = str(a)

# %%
c = 'My favorite number is ' + b

# %%
print(c)
# Out:
# My favorite number is2.54

# %%
from numpy import *

# %%
print(exp(1))
# Out:
# 2.718281828459045

# %%
a = arctan(pi/4)
print(a)
# Out:
# 0.6657737500283538

# %%
import numpy as np

# %%
a = np.cos(np.pi)

# %%
### Logical operators

# %%
a=1 #defines a

# %%
a ==1
# Out:
# True

# %%
a != 1
# Out:
# False

# %%
a is b
# Out:
# False

# %%
if a==1:
  print('Hello')
else:
  print('Bye')
# Out:
# Hello

# %%
if (a==1) and (b==2):
  print('Ok')

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,10,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
i=1
while (i<10):
  print(i)
  i= i*4
# Out:
# 1
# 4

# %%
f = lambda x: x + np.sin(x)
f(1)
# Out:
# 1.8414709848078965

# %%
def f(x):
  y = x + np.sin(x)

  return y

f(1)
# Out:
# 1.8414709848078965

# %%
x0 = 2.
tol = 1e-10
def f(x):
  """
  A useless function
  """
  y = x + np.sin(x)
  
  return y
  
x_old=x0
x= f(x_old)

i=1
while abs(x - x_old) > tol:
  x_old = x
  x = f(x_old)
  i += 1

print(x)
print(i)
# Out:
# 3.141592653589793
# 5

# %%
help(f)
# Out:
# Help on function f in module __main__:
#
# f(x)

# %%
## define Lists and tuples

# %%
a= [1, 2.5, 'abcd', False]
a[2]
id(a)
# Out:
# 139838180002224

# %%
b = (1, 2.5, 'abcd', False)
b[0]
id(b)
# Out:
# 139838180946960

# %%
#Lists are mutable
a= [1, 5, 3, 6]
b= a
a[1]=10
print(a)
print(b) # bir listse ve ben bunu diğerine eşitliyorsam sonrasında b de değişiyor
#çünkü listte değeri değiştirsen de adres aynı kalıyor. İkisinin de adresi aynı
# Out:
# [1, 10, 3, 6]
# [1, 10, 3, 6]

# %%
c= a.copy()

# %%
print(a)
# Out:
# [1, 10, 3, 6]

# %%
print(c)
# Out:
# [1, 10, 3, 6]

# %%
a[2] = 8

# %%
print(a)
print(c) #adresleri farklı
# Out:
# [1, 10, 8, 6]
# [1, 10, 3, 6]

# %%
# Tuples are not mutable
a = (1, 2, 3, 6)
a[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-8460423a7ca9> in <module>()
#       1 # Tuples are not mutable
#       2 a = (1, 2, 3, 6)
# ----> 3 a[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
b = a

# %%
a = (10, 2, 3, 6) # bu artık farklı tuple. you can not change the values of tuple
print(a)
print(b)
# Out:
# (10, 2, 3, 6)
# (1, 2, 3, 6)

# %%
a = [1, 2, 3]
b = [4, 5, 6]
a + b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a.append(7)
a
# Out:
# [1, 2, 3, 7]

# %%
a[0:3] # ilk 3 element same as a[:3]
a[-1] #last element
# Out:
# 7

# %%
a = [4, True, 'New York City', False]

for aa in a:
  print(aa)
# Out:
# 4
# True
# New York City
# False
